# %% [markdown]
# ### 1. To what does a relative path refer?

# %% [markdown]
# **_Relative path refers to the current working directory without any absolute path attached to it._**

# %%
pwd
# Out:
# '/Users/dhrumil/Documents/GitHub/iNeuron/Python/Assignments/Theory-based'

# %% [markdown]
# ### 2. What does an absolute path start with your operating system?

# %% [markdown]
# **_Absolute path starts with /._**

# %%
pwd
# Out:
# '/Users/dhrumil/Documents/GitHub/iNeuron/Python/Assignments/Theory-based'

# %% [markdown]
# ### 3. What do the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# **_os.getcwd() - Retrieves the current working directory. <br>
# os.chdir(path) - Changes the current working directory to the specified location._**

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/dhrumil/Documents/GitHub/iNeuron/Python/Assignments/Theory-based'

# %%
os.chdir("/Users/dhrumil/Documents/GitHub/iNeuron/Python")

# %%
os.getcwd()
# Out:
# '/Users/dhrumil/Documents/GitHub/iNeuron/Python'

# %% [markdown]
# ### 4. What are the . and .. folders?

# %% [markdown]
# **_. represents the current working directory._**

# %%
cd .
# Out:
# /Users/dhrumil/Documents/GitHub/iNeuron

# %% [markdown]
# **_.. represents a level up from the current working directory._**

# %%
pwd
# Out:
# '/Users/dhrumil/Documents/GitHub/iNeuron/Python/Assignments/Theory-based'

# %%
cd ..
# Out:
# /Users/dhrumil/Documents/GitHub/iNeuron/Python/Assignments

# %% [markdown]
# ### 5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

# %% [markdown]
# **_C:\bacon\eggs is dir name while spam.txt is the base name._**

# %% [markdown]
# ### 6. What are the three “mode” arguments that can be passed to the open() function?

# %% [markdown]
# **_read, write and append mode is passed as an argument for opening a file._**

# %% [markdown]
# ### 7. What happens if you open existing file in write mode?¶

# %% [markdown]
# **_The file gets overwritten eventhough it contained data inside it._**

# %% [markdown]
# ### 8.How do you tell the difference between read() and readlines()?

# %% [markdown]
# **_read() - Returns the entire file data in one single string value. <br>
# readlines() - Returns the list of string where each line is separated by \n at the end._**

# %% [markdown]
# ### 9. What data structure does a shelf value resemble?

# %% [markdown]
# **_A shelf resemble like a dictionary data structure._**

# %%
import shelve

# %%
with shelve.open('spam') as db:
    db['eggs'] = 'eggs'
