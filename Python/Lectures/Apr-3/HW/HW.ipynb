# %%
import shutil
import os
import re

# %%
downloadDirectory = os.chdir('C:\\Users\\dhrum\\Downloads\\New folder')

# %%
pwd()
# Out:
# 'C:\\Users\\dhrum\\Downloads\\New folder'

# %%
if not os.path.isdir('C:\\Users\\dhrum\\Downloads\\New folder\\Created Directory'):
    cd = os.mkdir('Created Directory',mode = 0o777)

# %%
pwd()
# Out:
# 'C:\\Users\\dhrum\\Downloads\\New folder'

# %%
os.listdir()
# Out:
# ['Assignment1.docx',
#  'Assignment10.docx',
#  'Assignment11.docx',
#  'Assignment12.docx',
#  'Assignment13.docx',
#  'Assignment14.docx',
#  'Assignment15.docx',
#  'Assignment16.docx',
#  'Assignment17.docx',
#  'Assignment18.docx',
#  'Assignment19.docx',
#  'Assignment2.docx',
#  'Assignment20.docx',
#  'Assignment21.docx',
#  'Assignment22.docx',
#  'Assignment23.docx',
#  'Assignment24.docx',
#  'Assignment25.docx',
#  'Assignment3.docx',
#  'Assignment4.docx',
#  'Assignment5.docx',
#  'Assignment6.docx',
#  'Assignment7.docx',
#  'Assignment8.docx',
#  'Assignment9.docx',
#  'Assignment_1 (1).docx',
#  'Assignment_1.docx',
#  'Assignment_10 (1).docx',
#  'Assignment_10.docx',
#  'Assignment_11 (1).docx',
#  'Assignment_11.docx',
#  'Assignment_12 (1).docx',
#  'Assignment_12.docx',
#  'Assignment_13 (1).docx',
#  'Assignment_13.docx',
#  'Assignment_14 (1).docx',
#  'Assignment_14.docx',
#  'Assignment_15 (1).docx',
#  'Assignment_15.docx',
#  'Assignment_16 (1).docx',
# ...

# %%
for i in os.listdir():
    print(i)
    if i == 'Created Directory':
        continue
    shutil.copy(i,'C:\\Users\\dhrum\\Downloads\\New folder\\Created Directory',follow_symlinks=True)
# Out:
# Assignment1.docx
# Assignment10.docx
# Assignment11.docx
# Assignment12.docx
# Assignment13.docx
# Assignment14.docx
# Assignment15.docx
# Assignment16.docx
# Assignment17.docx
# Assignment18.docx
# Assignment19.docx
# Assignment2.docx
# Assignment20.docx
# Assignment21.docx
# Assignment22.docx
# Assignment23.docx
# Assignment24.docx
# Assignment25.docx
# Assignment3.docx
# Assignment4.docx
# Assignment5.docx
# Assignment6.docx
# Assignment7.docx
# Assignment8.docx
# Assignment9.docx
# Assignment_1 (1).docx
# Assignment_1.docx
# Assignment_10 (1).docx
# Assignment_10.docx
# Assignment_11 (1).docx
# Assignment_11.docx
# Assignment_12 (1).docx
# Assignment_12.docx
# Assignment_13 (1).docx
# Assignment_13.docx
# Assignment_14 (1).docx
# Assignment_14.docx
# Assignment_15 (1).docx
# Assignment_15.docx
# Assignment_16 (1).docx
# Assignment_16.docx
# Assignment_17 (1).docx
# Assignment_17.docx
# Assignment_18 (1).docx
# Assignment_18.docx
# Assignment_19 (1).docx
# Assignment_19.docx
# ...

# %%
changedDirectory = os.chdir('C:\\Users\\dhrum\\Downloads\\New folder\\Created Directory')

# %%
print(os.listdir())
# Out:
# ['Assignment1.docx', 'Assignment10.docx', 'Assignment11.docx', 'Assignment12.docx', 'Assignment13.docx', 'Assignment14.docx', 'Assignment15.docx', 'Assignment16.docx', 'Assignment17.docx', 'Assignment18.docx', 'Assignment19.docx', 'Assignment2.docx', 'Assignment20.docx', 'Assignment21.docx', 'Assignment22.docx', 'Assignment23.docx', 'Assignment24.docx', 'Assignment25.docx', 'Assignment3.docx', 'Assignment4.docx', 'Assignment5.docx', 'Assignment6.docx', 'Assignment7.docx', 'Assignment8.docx', 'Assignment9.docx', 'Assignment_1 (1).docx', 'Assignment_1.docx', 'Assignment_10 (1).docx', 'Assignment_10.docx', 'Assignment_11 (1).docx', 'Assignment_11.docx', 'Assignment_12 (1).docx', 'Assignment_12.docx', 'Assignment_13 (1).docx', 'Assignment_13.docx', 'Assignment_14 (1).docx', 'Assignment_14.docx', 'Assignment_15 (1).docx', 'Assignment_15.docx', 'Assignment_16 (1).docx', 'Assignment_16.docx', 'Assignment_17 (1).docx', 'Assignment_17.docx', 'Assignment_18 (1).docx', 'Assignment_18.docx', 'As
# ...

# %%
for file in os.listdir():
    pattern =  re.compile(r"Assignment\d+.docx")
    matches = pattern.findall(file)
    for match in matches:
        print(match)
        
        if not os.path.isdir("E://Python Advanced programming"):
            os.mkdir("E://Python Advanced programming")
        shutil.copy(match,"E://Python Advanced programming")
# Out:
# Assignment1.docx
# Assignment10.docx
# Assignment11.docx
# Assignment12.docx
# Assignment13.docx
# Assignment14.docx
# Assignment15.docx
# Assignment16.docx
# Assignment17.docx
# Assignment18.docx
# Assignment19.docx
# Assignment2.docx
# Assignment20.docx
# Assignment21.docx
# Assignment22.docx
# Assignment23.docx
# Assignment24.docx
# Assignment25.docx
# Assignment3.docx
# Assignment4.docx
# Assignment5.docx
# Assignment6.docx
# Assignment7.docx
# Assignment8.docx
# Assignment9.docx

# %%
for file in os.listdir():
    pattern =  re.compile(r"Assignment_\d+.docx")
    matches = pattern.findall(file)
    for match in matches:
        print(match)
        
        if not os.path.isdir("E://PythonBasic"):
             os.mkdir("E://PythonBasic")
        shutil.copy(match,"E://PythonBasic")
# Out:
# Assignment_1.docx
# Assignment_10.docx
# Assignment_11.docx
# Assignment_12.docx
# Assignment_13.docx
# Assignment_14.docx
# Assignment_15.docx
# Assignment_16.docx
# Assignment_17.docx
# Assignment_18.docx
# Assignment_19.docx
# Assignment_2.docx
# Assignment_20.docx
# Assignment_21.docx
# Assignment_22.docx
# Assignment_23.docx
# Assignment_24.docx
# Assignment_25.docx
# Assignment_3.docx
# Assignment_4.docx
# Assignment_5.docx
# Assignment_6.docx
# Assignment_7.docx
# Assignment_8.docx
# Assignment_9.docx

# %%
Assignment_12 (1).docx

# %%
pwd()
# Out:
# 'C:\\Users\\dhrum\\Downloads\\New folder\\Temp'

# %%
for file in os.listdir():
    pattern =  re.compile(r"Assignment_\d+\s\(1\).docx")
#     Assignment_\d+\s\(1\)
    matches = pattern.findall(file)
    for match in matches:
            counter =  1
            print(match[0:13])
#             print(match[-5:])
            if not os.path.isdir("Temp"):
                os.mkdir("Temp")
            shutil.copy(match,"Temp")
    for file in os.listdir():
        print(file)
        counter = 1
        print(file[0:13]+str(counter)+file[-5:])
        
#         os.rename(file,match[0:13]+str(counter)+match[-5:])
        counter += 1
#         if not os.path.isdir("E://Python Advanced programming"):
#             os.mkdir("E://Python Advanced programming")
#         shutil.copy(match,"E://Python Advanced programming")
# Out:
# Assignment_1 1.docx
# Assignment_1 1.docx
# Assignment_10 (1).docx
# Assignment_101.docx
# Assignment_11 (1).docx
# Assignment_111.docx
# Assignment_12 (1).docx
# Assignment_121.docx
# Assignment_13 (1).docx
# Assignment_131.docx
# Assignment_14 (1).docx
# Assignment_141.docx
# Assignment_15 (1).docx
# Assignment_151.docx
# Assignment_16 (1).docx
# Assignment_161.docx
# Assignment_17 (1).docx
# Assignment_171.docx
# Assignment_18 (1).docx
# Assignment_181.docx
# Assignment_19 (1).docx
# Assignment_191.docx
# Assignment_2 (1).docx
# Assignment_2 1.docx
# Assignment_20 (1).docx
# Assignment_201.docx
# Assignment_21 (1).docx
# Assignment_211.docx
# Assignment_22 (1).docx
# Assignment_221.docx
# Assignment_23 (1).docx
# Assignment_231.docx
# Assignment_24 (1).docx
# Assignment_241.docx
# Assignment_25 (1).docx
# Assignment_251.docx
# Assignment_3 (1).docx
# Assignment_3 1.docx
# Assignment_4 (1).docx
# Assignment_4 1.docx
# Assignment_5 (1).docx
# Assignment_5 1.docx
# ...

# %%
for file in os.listdir():
    pattern =  re.compile(r"Programming_Assiment\d+.docx")
    matches = pattern.findall(file)
    for match in matches:
        print(match)
        
#         if not os.path.isdir("E://Python Advanced programming"):
#             os.mkdir("E://Python Advanced programming")
#         shutil.copy(match,"E://Python Advanced programming")
# Out:
# Programming_Assingment1.docx
# Programming_Assingment10.docx
# Programming_Assingment11.docx
# Programming_Assingment12.docx
# Programming_Assingment13.docx
# Programming_Assingment14.docx
# Programming_Assingment15.docx
# Programming_Assingment16.docx
# Programming_Assingment17.docx
# Programming_Assingment18.docx
# Programming_Assingment19.docx
# Programming_Assingment2.docx
# Programming_Assingment20.docx
# Programming_Assingment21.docx
# Programming_Assingment22.docx
# Programming_Assingment23.docx
# Programming_Assingment24.docx
# Programming_Assingment25.docx
# Programming_Assingment3.docx
# Programming_Assingment4.docx
# Programming_Assingment5.docx
# Programming_Assingment6.docx
# Programming_Assingment7.docx
# Programming_Assingment8.docx
# Programming_Assingment9.docx
