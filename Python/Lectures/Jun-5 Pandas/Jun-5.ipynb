# %%
import pandas as pd

# %%
pd = pd.read_csv("flavors.csv")

# %%
pd
# Out:
#           celery  vegetable
# 0           corn  vegetable
# 1       cucumber  vegetable
# 2    horseradish  vegetable
# 3      vegetable  vegetable
# 4         potato  vegetable
# ..           ...        ...
# 850         wild        NaN
# 851     wine-lee        NaN
# 852        winey        NaN
# 853       yeasty        NaN
# 854        ylang        NaN
#
# [855 rows x 2 columns]

# %%
pd.head()
# Out:
#         celery  vegetable
# 0         corn  vegetable
# 1     cucumber  vegetable
# 2  horseradish  vegetable
# 3    vegetable  vegetable
# 4       potato  vegetable

# %%
pd.head(20)
# Out:
#          celery   vegetable
# 0          corn   vegetable
# 1      cucumber   vegetable
# 2   horseradish   vegetable
# 3     vegetable   vegetable
# 4        potato   vegetable
# 5        tomato   vegetable
# 6       caraway  herbaceous
# 7         clove  herbaceous
# 8        fennel  herbaceous
# 9    herbaceous  herbaceous
# 10         sage  herbaceous
# 11       butter       fatty
# 12       cheese       fatty
# 13       creamy       fatty
# 14      hop_oil       fatty
# 15         oily       fatty
# 16        fatty       fatty
# 17         sour       fatty
# 18     coumarin       spicy
# 19        spicy       spicy

# %%
pd.tail()
# Out:
#        celery vegetable
# 850      wild       NaN
# 851  wine-lee       NaN
# 852     winey       NaN
# 853    yeasty       NaN
# 854     ylang       NaN

# %%
df = pd.read_csv("flavors.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df.head()

# %%
df.tail()
# Out:
#        celery vegetable
# 850      wild       NaN
# 851  wine-lee       NaN
# 852     winey       NaN
# 853    yeasty       NaN
# 854     ylang       NaN

# %%
df1.to_csv("test.csv")

# %%
pwd()
# Out:
# '/Users/dhrumil/Documents/GitHub/iNeuron/Python/Lectures/Jun-5 Pandas'

# %%
# !ls
# Out:
# Jun-5.ipynb flavors.csv test.csv

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0       celery  vegetable
# 0           0         corn  vegetable
# 1           1     cucumber  vegetable
# 2           2  horseradish  vegetable
# 3           3    vegetable  vegetable
# 4           4       potato  vegetable

# %%
df = pd.read_csv("flavors.csv",sep=',',header=None)

# %%
df
# Out:
#                0          1
# 0         celery  vegetable
# 1           corn  vegetable
# 2       cucumber  vegetable
# 3    horseradish  vegetable
# 4      vegetable  vegetable
# ..           ...        ...
# 851         wild        NaN
# 852     wine-lee        NaN
# 853        winey        NaN
# 854       yeasty        NaN
# 855        ylang        NaN
#
# [856 rows x 2 columns]

# %%
df = pd.read_csv("flavors.csv",sep=',',header=None,names=['a','b'])

# %%
df
# Out:
#                a          b
# 0         celery  vegetable
# 1           corn  vegetable
# 2       cucumber  vegetable
# 3    horseradish  vegetable
# 4      vegetable  vegetable
# ..           ...        ...
# 851         wild        NaN
# 852     wine-lee        NaN
# 853        winey        NaN
# 854       yeasty        NaN
# 855        ylang        NaN
#
# [856 rows x 2 columns]

# %%
df = pd.read_csv("flavors.csv",sep=',',header=None,names=['a','b'],skiprows=[0,2,4,6])

# %%
df
# Out:
#                a           b
# 0           corn   vegetable
# 1    horseradish   vegetable
# 2         potato   vegetable
# 3        caraway  herbaceous
# 4          clove  herbaceous
# ..           ...         ...
# 847         wild         NaN
# 848     wine-lee         NaN
# 849        winey         NaN
# 850       yeasty         NaN
# 851        ylang         NaN
#
# [852 rows x 2 columns]

# %%
df = pd.read_csv("flavors.csv",sep=',',na_values=['corn'])

# %%
df
# Out:
#           celery  vegetable
# 0            NaN  vegetable
# 1       cucumber  vegetable
# 2    horseradish  vegetable
# 3      vegetable  vegetable
# 4         potato  vegetable
# ..           ...        ...
# 850         wild        NaN
# 851     wine-lee        NaN
# 852        winey        NaN
# 853       yeasty        NaN
# 854        ylang        NaN
#
# [855 rows x 2 columns]

# %%
df.describe()
# Out:
#        celery vegetable
# count     854       112
# unique    854        27
# top      mold    fruity
# freq        1        24

# %%
df.dtypes
# Out:
# celery       object
# vegetable    object
# dtype: object

# %%
df = pd.read_csv("flavors.csv")

# %%
df1
# Out:
#         celery  vegetable
# 0         corn  vegetable
# 1     cucumber  vegetable
# 2  horseradish  vegetable
# 3    vegetable  vegetable
# 4       potato  vegetable

# %%
df1.to_csv("result.csv",index=False, header=False,sep='$')

# %%
df1.to_csv("result1.csv",index=False,sep='$',columns=['celery'])

# %%
df.tail()
# Out:
#        celery vegetable
# 850      wild       NaN
# 851  wine-lee       NaN
# 852     winey       NaN
# 853    yeasty       NaN
# 854     ylang       NaN

# %%
df.columns
# Out:
# Index(['celery', 'vegetable'], dtype='object')

# %%
df['celery']
# Out:
# 0             corn
# 1         cucumber
# 2      horseradish
# 3        vegetable
# 4           potato
#           ...
# 850           wild
# 851       wine-lee
# 852          winey
# 853         yeasty
# 854          ylang
# Name: celery, Length: 855, dtype: object

# %%
type(df['celery'])
# Out:
# pandas.core.series.Series

# %%
df[['celery']]
# Out:
#           celery
# 0           corn
# 1       cucumber
# 2    horseradish
# 3      vegetable
# 4         potato
# ..           ...
# 850         wild
# 851     wine-lee
# 852        winey
# 853       yeasty
# 854        ylang
#
# [855 rows x 1 columns]

# %%
type(df[['celery']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['celery','vegetable']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/ineuron/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('celery', 'vegetable')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-a0e3c758fef3> in <module>
# ...

# %%
df[['celery','vegetable']]
# Out:
#           celery  vegetable
# 0           corn  vegetable
# 1       cucumber  vegetable
# 2    horseradish  vegetable
# 3      vegetable  vegetable
# 4         potato  vegetable
# ..           ...        ...
# 850         wild        NaN
# 851     wine-lee        NaN
# 852        winey        NaN
# 853       yeasty        NaN
# 854        ylang        NaN
#
# [855 rows x 2 columns]

# %%
df2 =pd.read_excel("LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx",sheet_name='Add your take on balances')

# %%
df4 = pd.read_html("https://www.basketball-reference.com/players/j/jamesle01.html")

# %%
type(df4)
# Out:
# list

# %%
df4
# Out:
# [        Season   Age Team   Lg  Pos       G      GS    MP    FG   FGA  ...  \
#  0      2003-04  19.0  CLE  NBA   SG    79.0    79.0  39.5   7.9  18.9  ...
#  1      2004-05  20.0  CLE  NBA   SF    80.0    80.0  42.4   9.9  21.1  ...
#  2      2005-06  21.0  CLE  NBA   SF    79.0    79.0  42.5  11.1  23.1  ...
#  3      2006-07  22.0  CLE  NBA   SF    78.0    78.0  40.9   9.9  20.8  ...
#  4      2007-08  23.0  CLE  NBA   SF    75.0    74.0  40.4  10.6  21.9  ...
#  5      2008-09  24.0  CLE  NBA   SF    81.0    81.0  37.7   9.7  19.9  ...
#  6      2009-10  25.0  CLE  NBA   SF    76.0    76.0  39.0  10.1  20.1  ...
#  7      2010-11  26.0  MIA  NBA   SF    79.0    79.0  38.8   9.6  18.8  ...
#  8      2011-12  27.0  MIA  NBA   SF    62.0    62.0  37.5  10.0  18.9  ...
#  9      2012-13  28.0  MIA  NBA   PF    76.0    76.0  37.9  10.1  17.8  ...
#  10     2013-14  29.0  MIA  NBA   PF    77.0    77.0  37.7  10.0  17.6  ...
# ...

# %%
len(df4)
# Out:
# 6

# %%
df4[0]
# Out:
#         Season   Age Team   Lg  Pos       G      GS    MP    FG   FGA  ...  \
# 0      2003-04  19.0  CLE  NBA   SG    79.0    79.0  39.5   7.9  18.9  ...
# 1      2004-05  20.0  CLE  NBA   SF    80.0    80.0  42.4   9.9  21.1  ...
# 2      2005-06  21.0  CLE  NBA   SF    79.0    79.0  42.5  11.1  23.1  ...
# 3      2006-07  22.0  CLE  NBA   SF    78.0    78.0  40.9   9.9  20.8  ...
# 4      2007-08  23.0  CLE  NBA   SF    75.0    74.0  40.4  10.6  21.9  ...
# 5      2008-09  24.0  CLE  NBA   SF    81.0    81.0  37.7   9.7  19.9  ...
# 6      2009-10  25.0  CLE  NBA   SF    76.0    76.0  39.0  10.1  20.1  ...
# 7      2010-11  26.0  MIA  NBA   SF    79.0    79.0  38.8   9.6  18.8  ...
# 8      2011-12  27.0  MIA  NBA   SF    62.0    62.0  37.5  10.0  18.9  ...
# 9      2012-13  28.0  MIA  NBA   PF    76.0    76.0  37.9  10.1  17.8  ...
# 10     2013-14  29.0  MIA  NBA   PF    77.0    77.0  37.7  10.0  17.6  ...
# ...

# %%
df4[3].to_csv('player_data.csv')

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name" : "dhru",
"phone_no" : 343431,
"comp" : ["iNeuron", "EY", "unilever", "verizon", "deloitte", "wipro"]
}
"""

# %%
import json

# %%
s1 = json.loads(s)

# %%
pd.DataFrame(s1)
# Out:
#    name  phone_no      comp
# 0  dhru    343431   iNeuron
# 1  dhru    343431        EY
# 2  dhru    343431  unilever
# 3  dhru    343431   verizon
# 4  dhru    343431  deloitte
# 5  dhru    343431     wipro

# %%
pd.DataFrame(s1,columns=['comp'])
# Out:
#        comp
# 0   iNeuron
# 1        EY
# 2  unilever
# 3   verizon
# 4  deloitte
# 5     wipro

# %%
# !pip install requests
# Out:
# ...
#      |████████████████████████████████| 61 kB 3.3 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 178 kB 5.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 138 kB 2.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 1.4 MB/s eta 0:00:01
# ...

# %%
import requests

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js = res.json()

# %%
js[0]['title']
# Out:
# 'PERF: groupsort_indexer contiguity'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# PERF: groupsort_indexer contiguity
# Regression raising Error when having dup cols with single dtype for read csv
# Backport PR #41972 on branch 1.3.x (PERF: indexing on UInt64Index with int64s)
# Backport PR #41958 on branch 1.3.x (REGR: Series[dt64/td64].astype(string))
# Backport PR #42024 on branch 1.3.x (TST: Reduce number of numba tests run)
# CI: fsspec 2021.6.0 failures
# CI: pin fsspec
# BUG: read_csv now errors with non-dict dtype and same-name columns
# BUG: passing str to GroupBy.apply
# Fix module name for _LoadSparseFrame
# DOC: Fix wrongly associated docstring of Series.str.isspace
# BUG: groupby with dropna=False and 'unique' aggregate creates duplicated index
# DOC: pandas.Series.str.isspace has wrong documentation
# BUG: `Styler.apply` consistently manages Series return objects aligning labels.
# Updated the docstring for reset_index in frame.py
# ENH/PERF: optional mask in nullable dtypes
# DOC: Add New Community Tutorial
# ...

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42031',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42031/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42031/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42031/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42031',
#   'id': 921831711,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjcwNzc1OTc5',
#   'number': 42031,
#   'title': 'PERF: groupsort_indexer contiguity',
#   'user': {'login': 'mzeitlin11',
#    'id': 37011898,
#    'node_id': 'MDQ6VXNlcjM3MDExODk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37011898?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mzeitlin11',
#    'html_url': 'https://github.com/mzeitlin11',
# ...

# %%
df4 = pd.DataFrame(js)

# %%
df4.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'mzeitlin11',
#  'id': 37011898,
#  'node_id': 'MDQ6VXNlcjM3MDExODk4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/37011898?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mzeitlin11',
#  'html_url': 'https://github.com/mzeitlin11',
#  'followers_url': 'https://api.github.com/users/mzeitlin11/followers',
#  'following_url': 'https://api.github.com/users/mzeitlin11/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mzeitlin11/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mzeitlin11/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mzeitlin11/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mzeitlin11/orgs',
#  'repos_url': 'https://api.github.com/users/mzeitlin11/repos',
#  'events_url': 'https://api.github.com/users/mzeitlin11/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mzeitlin11/received_events',
#  'type': 'User',
# ...

# %%
li = []
for i in range(len(js)):
    li.append(js[i]['user'])

# %%
pd.DataFrame(li)
# Out:
#                  login        id               node_id  \
# 0           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 1                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 2      meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 3      meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 4      meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 5           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 6           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 7             fiendish    201996  MDQ6VXNlcjIwMTk5Ng==
# 8         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9              eltoder   4088528  MDQ6VXNlcjQwODg1Mjg=
# 10           felixdivo   4403130  MDQ6VXNlcjQ0MDMxMzA=
# 11             mhabets   2016449  MDQ6VXNlcjIwMTY0NDk=
# 12           felixdivo   4403130  MDQ6VXNlcjQ0MDMxMzA=
# 13            attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 14             cf-vrgl  82909524  MDQ6VXNlcjgyOTA5NTI0
# 15          mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# ...
