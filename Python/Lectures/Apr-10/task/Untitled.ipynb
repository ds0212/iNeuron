# %%
import mo1
import logging as lg

# %%
lg.basicConfig(filename = 'even.log',level = lg.ERROR , format  = '%(asctime)s %(message)s')

while True:
    try:
        inp = int(input())
    except ValueError as e:
        lg.error(e)
    except Exception as e:
        lg.error(e)
    else:
        mo1.even_num(inp)
        break
# Out:
# l

# %%
import logging as lg

lg.basicConfig(filename = 'even.log',level = lg.INFO , format  = '%(asctime)s %(message)s')


def even(minimum,maximum):
    try:
        minimum = int(input("Enterthe start value: "))
        maximum = int(input("Enter the end value: "))
    except Exception as e:
        lg.error(e)
    else:
        for i in range(minimum,maximum+1):
            if i%2==0:
                print(i,"even number")
    finally:
        print("code executed")

# %%
even(a,gb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bcec5c29b1c0> in <module>
# ----> 1 even(a,gb)
#
# NameError: name 'a' is not defined

# %%
import logging as lg

lg.basicConfig(filename = 'even.log',level = lg.INFO , format  = '%(asctime)s %(message)s')


def even(minimum,maximum):
    try:
        minimum = int(input("Enterthe start value: "))
        maximum = int(input("Enter the end value: "))
    except Exception as e:
        lg.error(e)
    else:
        for i in range(minimum,maximum+1):
            if i%2==0:
                print(i,"even number")
    finally:
        print("code executed")
