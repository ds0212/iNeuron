# %%
import test_dir.mod1, test_dir.mod2,  test_dir.mod3

# %%
test_dir.mod1.fn1()
# Out:
# Hello how's it going?

# %%
test_dir.mod2.fn21()
# Out:
# Mod2 python module.

# %%
test_dir.mod3.fn31()
# Out:
# Inside mod3
