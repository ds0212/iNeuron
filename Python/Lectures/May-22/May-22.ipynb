# %%
pip install cassandra-driver
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 5.0 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cassandra
print (cassandra.__version__)
# Out:
# 3.25.0

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/Users/dhrumil/Downloads/secure-connect-test.zip'
}
auth_provider = PlainTextAuthProvider('OvCpYpGuGLkMFaeyyRfpPEnp', 'xpSIKi0NQ7DZSRbdDjnWt+fL9MQJqJBa0.K3AsXPz7fjWlm9aZF0BfLDfTPwhoUzlUAQ.ob1xsqYWDUeWqf.YriWuHurnIGG1S-sK+Ds4xAC,II7jdWACGy_i9aCJjj+')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# 4.0.0.6813

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("select release_version from system.local").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# An error occurred.

# %%
CREATE KEYSPACE home1 WITH replication = {'class': 'SimpleStrategy', 'replication_factor' : 3} AND durable_writes = 'true';

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("select release_version from system.local").one()
if row:
    print(row)
else:
    print("An error occurred.")
# Out:
# Row(release_version='3.11.10')

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("CREATE KEYSPACE home3 WITH replication = {'class': 'SimpleStrategy', 'replication_factor' : 3} AND durable_writes = 'true';").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# An error occurred.

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("USE home3").one()
if row:
    print(row[0])

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/Users/dhrumil/Downloads/secure-connect-test.zip'
}
auth_provider = PlainTextAuthProvider('OvCpYpGuGLkMFaeyyRfpPEnp', 'xpSIKi0NQ7DZSRbdDjnWt+fL9MQJqJBa0.K3AsXPz7fjWlm9aZF0BfLDfTPwhoUzlUAQ.ob1xsqYWDUeWqf.YriWuHurnIGG1S-sK+Ds4xAC,II7jdWACGy_i9aCJjj+')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("DESCRIBE ineuron").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# ---------------------------------------------------------------------------
# SyntaxException                           Traceback (most recent call last)
# <ipython-input-19-74d6d23a5351> in <module>
#       9 session = cluster.connect()
#      10
# ---> 11 row = session.execute("DESCRIBE ineuron").one()
#      12 if row:
#      13     print(row[0])
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.Session.execute()
#
# /opt/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-darwin.so in cassandra.cluster.ResponseFuture.result()
#
# SyntaxException: <Error from server: code=2000 [Syntax error in CQL query] message="line 1:0 no viable alternative at input 'DESCRIBE' ([DESCRIBE]...)">

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("SELECT * FROM system_schema.keyspaces").one()
if row:
    print(row)
# Out:
# Row(keyspace_name='home3', durable_writes=True, replication=OrderedMapSerializedKey([('class', 'org.apache.cassandra.locator.SimpleStrategy'), ('replication_factor', '3')]))

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/Users/dhrumil/Downloads/secure-connect-test.zip'
}
auth_provider = PlainTextAuthProvider('OvCpYpGuGLkMFaeyyRfpPEnp', 'xpSIKi0NQ7DZSRbdDjnWt+fL9MQJqJBa0.K3AsXPz7fjWlm9aZF0BfLDfTPwhoUzlUAQ.ob1xsqYWDUeWqf.YriWuHurnIGG1S-sK+Ds4xAC,II7jdWACGy_i9aCJjj+')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("SELECT * FROM system_schema.keyspaces").one()
if row:
    print(row)
else:
    print("An error occurred.")
# Out:
# Row(keyspace_name='datastax_sla', durable_writes=True, graph_engine=None, replication=OrderedMapSerializedKey([('class', 'org.apache.cassandra.locator.NetworkTopologyStrategy'), ('us-east-1', '3')]))

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/Users/dhrumil/Downloads/secure-connect-test.zip'
}
auth_provider = PlainTextAuthProvider('OvCpYpGuGLkMFaeyyRfpPEnp', 'xpSIKi0NQ7DZSRbdDjnWt+fL9MQJqJBa0.K3AsXPz7fjWlm9aZF0BfLDfTPwhoUzlUAQ.ob1xsqYWDUeWqf.YriWuHurnIGG1S-sK+Ds4xAC,II7jdWACGy_i9aCJjj+')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("CREATE TABLE ineuron.emp(emp_id int PRIMARY KEY, emp_name text, emp_city text, emp_sal varint, emp_phone varint);").one()
print(row)
# Out:
# None

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("CREATE TABLE home1.emp(emp_id int PRIMARY KEY, emp_name text, emp_city text, emp_sal varint, emp_phone varint);").one()
print(row)
# Out:
# None

# %%
from cassandra.cluster import Cluster

cluster = Cluster()

session_offline = cluster.connect()

row = session_offline.execute("SELECT * from home1.emp;").one()
print(row)
# Out:
# None

# %%
CREATE TABLE home1.emp1(emp_id INT PRIMARY KEY, emp_age INT);

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/Users/dhrumil/Downloads/secure-connect-test.zip'
}
auth_provider = PlainTextAuthProvider('OvCpYpGuGLkMFaeyyRfpPEnp', 'xpSIKi0NQ7DZSRbdDjnWt+fL9MQJqJBa0.K3AsXPz7fjWlm9aZF0BfLDfTPwhoUzlUAQ.ob1xsqYWDUeWqf.YriWuHurnIGG1S-sK+Ds4xAC,II7jdWACGy_i9aCJjj+')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("CREATE TABLE ineuron.emp1(emp_id INT PRIMARY KEY, emp_age INT);").one()
print(row)
# Out:
# None

# %%
session.execute("INSERT INTO ineuron.emp1(emp_id,emp_age) VALUES(1,21);")
