# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host='localhost', database='dhrumil12345', user='root', passwd='dhrumil212', use_pure=True)

# %%
mydb

# %%
query= 'DELETE FROM dhrumil12345.studentdetails WHERE studentid = 1122'
cursor= mydb.cursor()

# %%
cursor.execute(query)
mydb.commit()

# %%
query = 'SELECT * FROM studentdetails where studentid=1122;'
cursor= mydb.cursor()
cursor.execute(query)
for result in cursor.fetchall():
    print(result)
mydb.close()

# %%
query = "UPDATE dhrumil12345.studentdetails SET FirstName='Kumar', LastName='Gaurav'"
cursor=mydb.cursor()
cursor.execute(query)
mydb.commit()

# %%
cursor.fetchall()
# Out:
# [(132, 'Kumar', 'Gaurav', datetime.date(1997, 12, 2), 'Eleventh', 'A')]

# %%
query = 'SELECT * FROM studentdetails where studentid=132;'
cursor= mydb.cursor()
cursor.execute(query)

# %%
# !python -m pip install pymongo
# Out:
# ...
#      |████████████████████████████████| 380 kB 1.1 MB/s eta 0:00:01
# ...

# %%
# !pip install pymongo[srv]
# Out:
# ...
#      |████████████████████████████████| 188 kB 2.5 MB/s eta 0:00:01
# ...

# %%
import pymongo

# %%
client_cloud = pymongo.MongoClient("mongodb+srv://test:test@cluster0.he6iz.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client_cloud.test

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
client_cloud
# Out:
# MongoClient(host=['cluster0-shard-00-00.he6iz.mongodb.net:27017', 'cluster0-shard-00-02.he6iz.mongodb.net:27017', 'cluster0-shard-00-01.he6iz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-u119vl-shard-0', ssl=True)

# %%
DB_NAME = 'iNeuron'
db1 = client[DB_NAME]

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
record = {'companyName' : 'iNeuron',
         'product': 'Affordable AI',
         'course' :'Full stack DS',
         'name' : ['dhrumil','sanghvi', 212],
         'record_dict' : {"name":'dhrumil','mail_id':'dhrumil@ineuron.ai','phone_no':222}}

# %%
db1
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'iNeuron')

# %%
collection = db1["test"]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'iNeuron'), 'test')

# %%
collection.insert_one(record)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program',
    "test" : "ffsdfsffsf",
     "complex" : [{"name" : "dhrumil","list" : [554,545,454,54,5,4]},{"email_id" :"dhrumil@ineuron.ai"},{"phone_no":212},[4,54,534,5,45,5,45,4]]
    }]
    
rec = collection.insert_many(list_of_records)
