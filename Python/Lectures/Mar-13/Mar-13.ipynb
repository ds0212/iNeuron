# %%
a = 'dhru'

# %%
b = "dhru"

# %%
print(a)
print(b)
# Out:
# dhru
# dhru

# %%
c = 'this is my first class for fullstak data science, that"s why I have joined this class.'

# %%
c
# Out:
# 'this is my first class for fullstak data science, that"s why I have joined this class'

# %%
s = 'this is full stack class.'

# %%
s[0]
# Out:
# 't'

# %%
s[-1]
# Out:
# 's'

# %%
len(s)
# Out:
# 24

# %%
s[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-2a138df92e52> in <module>
# ----> 1 s[100]
#
# IndexError: string index out of range

# %%
s[4:10:1] #excluding upper bound
# Out:
# ' is fu'

# %%
s[-1:-10:-1]
# Out:
# 'ssalc kca'

# %%
s
# Out:
# 'this is full stack class'

# %%
for i in s:
    print(i,end='')
# Out:
# this is full stack class

# %%
for i in range(len(s)):
    print(s[i])
# Out:
# t
# h
# i
# s
#
# i
# s
#
# f
# u
# l
# l
#
# s
# t
# a
# c
# k
#
# c
# l
# a
# s
# s

# %%
for i in range(-1,-24,-1):
    print(s[i],end='')
# Out:
# ssalc kcats lluf si sih

# %%
# String is an immutable object.

# %%
s[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-fa085c53b004> in <module>
# ----> 1 s[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %%
l =['adfas', 123, 46.0, True]

# %%
l[0]
# Out:
# 'adfas'

# %%
l[0] = 'dhru'

# %%
l
# Out:
# ['dhru', 123, 46.0, True]

# %%
"dhru" +3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-5a1cd6023b68> in <module>
# ----> 1 "dhru" +3
#
# TypeError: can only concatenate str (not "int") to str

# %%
'dhru' + '3'
# Out:
# 'dhru3'

# %%
'dhru' + str(3)
# Out:
# 'dhru3'

# %%
'dhru' + ['mil', 3,453]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-38c72a33946d> in <module>
# ----> 1 'dhru' + ['mil', 3,453]
#
# TypeError: can only concatenate str (not "list") to str

# %%
'dhru' * 6
# Out:
# 'dhrudhrudhrudhrudhrudhru'

# %%
s = 'my name is dhrumil'

# %%
s.find('m')
# Out:
# 0

# %%
s.find('mn')
# Out:
# -1

# %%
s = 'my name is '
b = s.find('name')
for i in range(b+1):
    print(b+i)
# Out:
# 3
# 4
# 5
# 6

# %%
s = 'my name is '
b = s.find('name')
for i in range(len('name')):
    print(s[b])
    b = (b+1)
# Out:
# n
# a
# m
# e

# %%
s.count('m')
# Out:
# 2

# %%
s = 'my name is Dhrumil'

# %%
s.split()
# Out:
# ['my', 'name', 'is', 'dhrumil']

# %%
s.upper()
# Out:
# 'MY NAME IS DHRUMIL'

# %%
s.lower()
# Out:
# 'my name is dhrumil'

# %%
s.swapcase()
# Out:
# 'MY NAME IS dHRUMIL'

# %%
" ".join(s)
# Out:
# 'm y   n a m e   i s   D h r u m i l'

# %%
 reversed(s)

# %%
for i in reversed(s):
    print(i,end='')
# Out:
# limurhD si eman ym

# %%
# if object is returned try to perform an itereation over it.

# %%
s = '      dhru      '

# %%
s.strip()
# Out:
# 'dhru'

# %%
s.lstrip()
# Out:
# 'dhru      '

# %%
s.rstrip()
# Out:
# '      dhru'

# %%
s = 'greetings from ineuron'

# %%
s.replace('gr','ser')
# Out:
# 'sereetings from ineuron'

# %%
s
# Out:
# 'greetings from ineuron'

# %%
s ='dhru'

# %%
s.center(20,'#')
# Out:
# '########dhru########'

# %%
s = 'dhrum \t hii'

# %%
s
# Out:
# 'dhrum \t hii'

# %%
s.expandtabs()
# Out:
# 'dhrum    hii'

# %%
a = 'we all are a part of Full stack'
print(a.upper())
print(a.count('a'))
for i in range(len(a)):
    if a[i] == 'a':
        print(i)
print(a.replace('a','iNeuron'))   
l=a.split()
print(l)
# Out:
# WE ALL ARE A PART OF FULL STACK
# 5
# 3
# 7
# 11
# 14
# 28
# we iNeuronll iNeuronre iNeuron piNeuronrt of Full stiNeuronck
# ['we', 'all', 'are', 'a', 'part', 'of', 'Full', 'stack']

# %%
s.isalnum()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
a = '       '

# %%
a.isspace()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
s.endswith('s')
# Out:
# False

# %%
s.startswith('a')
# Out:
# False

# %%
s.isalnum()
# Out:
# False

# %%
s = 'dhru'

# %%
s.isalpha()
# Out:
# True

# %%
s.istitle()
# Out:
# False

# %%
s = 'this is a full stack batch'
count = 0
for i in s:
    count = count+1

# %%
print(count)
# Out:
# 26

# %%
for i in range(len(s)):
    print(s[i])
# Out:
# t
# h
# i
# s
#
# i
# s
#
# a
#
# f
# u
# l
# l
#
# s
# t
# a
# c
# k
#
# b
# a
# t
# c
# h

# %%
s
# Out:
# 'this is a full stack batch'

# %%
for i in range(len(s)):
    print(s[-i])
# Out:
# t
# h
# c
# t
# a
# b
#
# k
# c
# a
# t
# s
#
# l
# l
# u
# f
#
# a
#
# s
# i
#
# s
# i
# h

# %%
s = 'dhru'
ch = len(s) - 1
while ch >= 0 :
    print(s[ch])
    ch = ch - 1
# Out:
# u
# r
# h
# d

# %%
name = 'iNeuron'
a = 'AaEeiIoOuU'
for i in name:
    if i in a:
        print('Vowel found:',i)
    else:
        print('Not a vowel:',i)
# Out:
# Vowel found: i
# Not a vowel: N
# Vowel found: e
# Vowel found: u
# Not a vowel: r
# Vowel found: o
# Not a vowel: n

# %%
a = 'xyx'
b = 2002
c = 'eye'
d = 'nitin'

# %%
s = input('Enter a string to be checked: ')
s1 = s[::-1]
if s == s1:
    print('It is the same')
else:
    print('It is not the same')
# Out:
# Enter a string to be checked: aga
# It is the same

# %%
l = ['dhrumil', 212, 212.0, True,[33,36]]

# %%
l[3]
# Out:
# True

# %%
l[0:3]
# Out:
# ['dhrumil', 212, 212.0]

# %%
l[0:3:-1]
# Out:
# []

# %%
l[3:0:-1]
# Out:
# [True, 212.0, 212]

# %%
l[::-1]
# Out:
# [[33, 36], True, 212.0, 212, 'dhrumil']

# %%
l
# Out:
# ['dhrumil', 212, 212.0, True, [33, 36]]

# %%
s = 'dhru'

# %%
s+l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-8c604c14fd91> in <module>
# ----> 1 s+l
#
# TypeError: can only concatenate str (not "list") to str

# %%
s = list(s)

# %%
s
# Out:
# ['d', 'h', 'r', 'u']

# %%
l+s
# Out:
# ['dhrumil', 212, 212.0, True, [33, 36], 'd', 'h', 'r', 'u']

# %%
s = ['dhru']

# %%
l+s
# Out:
# ['dhrumil', 212, 212.0, True, [33, 36], 'dhru']

# %%
s +l
# Out:
# ['dhru', 'dhrumil', 212, 212.0, True, [33, 36]]

# %%
l
# Out:
# ['dhrumil', 212, 212.0, True, [33, 36]]

# %%
l * 2
# Out:
# ['dhrumil', 212, 212.0, True, [33, 36], 'dhrumil', 212, 212.0, True, [33, 36]]

# %%
len(l) # Number of elements
# Out:
# 5

# %%
l
# Out:
# ['dhrumil', 212, 212.0, True, [33, 36]]

# %%
'dhrumil' in l
# Out:
# True

# %%
4545 in l
# Out:
# False
